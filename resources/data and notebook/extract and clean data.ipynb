# %%
#imports
import pandas as pd
import csv
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

from geopy.geocoders import Nominatim 
import plotly.express as px   
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots

from dotenv import load_dotenv
import os
import pycountry
import stylecloud
from wordcloud import WordCloud 

import panel as pn
pn.extension('plotly')
import hvplot.pandas

# %%
# Read the Mapbox API key
load_dotenv()
map_box_api = os.getenv("mapbox")
px.set_mapbox_access_token(map_box_api)

# %%
# Read in International tourism number of arrivals 
intl_tourism_flights_arrival_path = Path('INTL_TOURISM_ARRIVALS.csv')
intl_tourism_flights_arrival = pd.read_csv(intl_tourism_flights_arrival_path)

# %%
# Look at head of dataframe
intl_tourism_flights_arrival.head()
# Out:
#                  Country Name Country Code  \
# 0                       Aruba          ABW
# 1                 Afghanistan          AFG
# 2  Africa Western and Central          AFW
# 3                      Angola          AGO
# 4                     Albania          ALB
#
#                               Indicator Name Indicator Code  1960  1961  1962  \
# 0  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 1  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 2  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 3  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 4  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
#
#    1963  1964  1965  ...         2011        2012         2013        2014  \
# 0   NaN   NaN   NaN  ...  1469000.000   1481000.0   1667000.00   1739000.0
# 1   NaN   NaN   NaN  ...          NaN         NaN          NaN         NaN
# 2   NaN   NaN   NaN  ...  8902380.178  10221030.4  10085818.94  10544624.0
# 3   NaN   NaN   NaN  ...   481000.000    528000.0    650000.00    595000.0
# 4   NaN   NaN   NaN  ...  2932000.000   3514000.0   3256000.00   3673000.0
#
#           2015         2016       2017       2018       2019  2020
# 0   1832000.00   1758000.00  1863000.0  1897000.0  1951000.0   NaN
# 1          NaN          NaN        NaN        NaN        NaN   NaN
# 2  13311681.73  13150775.34        NaN        NaN        NaN   NaN
# 3    592000.00    397000.00   261000.0   218000.0   218000.0   NaN
# 4   4131000.00   4736000.00  5118000.0  5927000.0  6406000.0   NaN
#
# [5 rows x 65 columns]

# %%
# Look at tail of dataframe
intl_tourism_flights_arrival.tail()
# Out:
#      Country Name Country Code                             Indicator Name  \
# 212        Kosovo          XKX  International tourism, number of arrivals
# 213         Yemen          YEM  International tourism, number of arrivals
# 214  South Africa          ZAF  International tourism, number of arrivals
# 215        Zambia          ZMB  International tourism, number of arrivals
# 216      Zimbabwe          ZWE  International tourism, number of arrivals
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...        2011  \
# 212    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...         NaN
# 213    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...   1175000.0
# 214    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...  12097000.0
# 215    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...    920000.0
# 216    ST.INT.ARVL   NaN   NaN   NaN   NaN   NaN   NaN  ...   2423000.0
#
#            2012        2013        2014        2015        2016        2017  \
# 212         NaN         NaN         NaN         NaN         NaN         NaN
# 213   1282000.0   1323000.0   1218000.0    398000.0         NaN         NaN
# 214  13069000.0  14318000.0  14530000.0  13952000.0  15121000.0  14975000.0
# 215    859000.0    915000.0    947000.0    932000.0    956000.0   1009000.0
# 216   1794000.0   1833000.0   1880000.0   2057000.0   2168000.0   2423000.0
#
#            2018        2019  2020
# 212         NaN         NaN   NaN
# 213         NaN         NaN   NaN
# 214  15004000.0  14797000.0   NaN
# 215   1072000.0   1266000.0   NaN
# 216   2580000.0   2294000.0   NaN
#
# [5 rows x 65 columns]

# %%
#Use GeoPy to obtain latitude and longitude for each country
country_names = intl_tourism_flights_arrival['Country Name']

longitude =[]
latitude =[]
geolocator = Nominatim(user_agent="Arrival")

for c in country_names.values:
    location = geolocator.geocode(c)
    if location is not None:
        latitude.append(location.latitude)
        longitude.append(location.longitude)
    else:
        print(f"Could not find Location for {c!r}")

# %%
# Create lat and lon columns for dataframe
intl_tourism_flights_arrival['Latitude'] = latitude
intl_tourism_flights_arrival['Longitude'] = longitude

# %%
# Check the head of dataframe to ensure latitude and longitude are added
intl_tourism_flights_arrival.head()
# Out:
#                  Country Name Country Code  \
# 0                       Aruba          ABW
# 1                 Afghanistan          AFG
# 2  Africa Western and Central          AFW
# 3                      Angola          AGO
# 4                     Albania          ALB
#
#                               Indicator Name Indicator Code  1960  1961  1962  \
# 0  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 1  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 2  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 3  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 4  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
#
#    1963  1964  1965  ...         2013        2014         2015         2016  \
# 0   NaN   NaN   NaN  ...   1667000.00   1739000.0   1832000.00   1758000.00
# 1   NaN   NaN   NaN  ...          NaN         NaN          NaN          NaN
# 2   NaN   NaN   NaN  ...  10085818.94  10544624.0  13311681.73  13150775.34
# 3   NaN   NaN   NaN  ...    650000.00    595000.0    592000.00    397000.00
# 4   NaN   NaN   NaN  ...   3256000.00   3673000.0   4131000.00   4736000.00
#
#         2017       2018       2019  2020   Latitude  Longitude
# 0  1863000.0  1897000.0  1951000.0   NaN  12.490300 -69.960984
# 1        NaN        NaN        NaN   NaN  33.768006  66.238514
# 2        NaN        NaN        NaN   NaN   5.267047  28.792421
# 3   261000.0   218000.0   218000.0   NaN -11.877577  17.569124
# 4  5118000.0  5927000.0  6406000.0   NaN  41.000028  19.999962
#
# [5 rows x 67 columns]

# %%
# Check columns in dataframe
intl_tourism_flights_arrival.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
# Delete columns we won't use
intl_tourism_flights_arrival.drop(['Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '2020'], axis=1, inplace=True)

# %%
# Check head of dataframe to ensure columns are dropped
intl_tourism_flights_arrival.head()
# Out:
#                  Country Name Country Code         1995         1996  \
# 0                       Aruba          ABW   912000.000   957000.000
# 1                 Afghanistan          AFG          NaN          NaN
# 2  Africa Western and Central          AFW  2670705.934  3027134.733
# 3                      Angola          AGO     9000.000    21000.000
# 4                     Albania          ALB   304000.000   287000.000
#
#           1997         1998         1999         2000         2001  \
# 0   947000.000   906000.000   972000.000  1211000.000  1178000.000
# 1          NaN          NaN          NaN          NaN          NaN
# 2  3243144.347  3422652.337  3897975.031  4162850.003  4615887.342
# 3    45000.000    52000.000    45000.000    51000.000    67000.000
# 4   119000.000   184000.000   371000.000   317000.000   354000.000
#
#          2002  ...        2012         2013        2014         2015  \
# 0  1225000.00  ...   1481000.0   1667000.00   1739000.0   1832000.00
# 1         NaN  ...         NaN          NaN         NaN          NaN
# 2  4697120.11  ...  10221030.4  10085818.94  10544624.0  13311681.73
# 3    91000.00  ...    528000.0    650000.00    595000.0    592000.00
# 4   470000.00  ...   3514000.0   3256000.00   3673000.0   4131000.00
#
#           2016       2017       2018       2019   Latitude  Longitude
# 0   1758000.00  1863000.0  1897000.0  1951000.0  12.490300 -69.960984
# 1          NaN        NaN        NaN        NaN  33.768006  66.238514
# 2  13150775.34        NaN        NaN        NaN   5.267047  28.792421
# 3    397000.00   261000.0   218000.0   218000.0 -11.877577  17.569124
# 4   4736000.00  5118000.0  5927000.0  6406000.0  41.000028  19.999962
#
# [5 rows x 29 columns]

# %%
# Move Lat and Long columns to beginning of dataframe
def reorder_columns(dataframe, col_name, position):
    temp_col = dataframe[col_name]
    dataframe = dataframe.drop(columns=[col_name])
    dataframe.insert(loc=position, column=col_name, value=temp_col)
    return dataframe

intl_tourism_flights_arrival = reorder_columns(dataframe=intl_tourism_flights_arrival, col_name='Latitude', position=2)
intl_tourism_flights_arrival = reorder_columns(dataframe=intl_tourism_flights_arrival, col_name='Longitude', position=3)
intl_tourism_flights_arrival
# Out:
#                    Country Name Country Code   Latitude  Longitude  \
# 0                         Aruba          ABW  12.490300 -69.960984
# 1                   Afghanistan          AFG  33.768006  66.238514
# 2    Africa Western and Central          AFW   5.267047  28.792421
# 3                        Angola          AGO -11.877577  17.569124
# 4                       Albania          ALB  41.000028  19.999962
# ..                          ...          ...        ...        ...
# 212                      Kosovo          XKX  42.586958  20.902123
# 213                       Yemen          YEM  16.347124  47.891527
# 214                South Africa          ZAF -28.816624  24.991639
# 215                      Zambia          ZMB -14.518912  27.558988
# 216                    Zimbabwe          ZWE -18.455496  29.746841
#
#             1995         1996         1997         1998         1999  \
# 0     912000.000   957000.000   947000.000   906000.000   972000.000
# 1            NaN          NaN          NaN          NaN          NaN
# 2    2670705.934  3027134.733  3243144.347  3422652.337  3897975.031
# 3       9000.000    21000.000    45000.000    52000.000    45000.000
# 4     304000.000   287000.000   119000.000   184000.000   371000.000
# ..           ...          ...          ...          ...          ...
# 212          NaN          NaN          NaN          NaN          NaN
# 213          NaN          NaN          NaN          NaN          NaN
# 214  4684000.000  5186000.000  5170000.000  5898000.000  6026000.000
# 215   163000.000   264000.000   341000.000   362000.000   404000.000
# 216  1416000.000  1597000.000  1336000.000  2090000.000  2250000.000
#
#             2000  ...         2010          2011        2012         2013  \
# 0    1211000.000  ...   1394000.00  1.469000e+06   1481000.0   1667000.00
# 1            NaN  ...          NaN           NaN         NaN          NaN
# 2    4162850.003  ...  11070796.45  8.902380e+06  10221030.4  10085818.94
# 3      51000.000  ...    425000.00  4.810000e+05    528000.0    650000.00
# 4     317000.000  ...   2417000.00  2.932000e+06   3514000.0   3256000.00
# ..           ...  ...          ...           ...         ...          ...
# 212          NaN  ...          NaN           NaN         NaN          NaN
# 213          NaN  ...   1035000.00  1.175000e+06   1282000.0   1323000.00
# 214  6001000.000  ...  11303000.00  1.209700e+07  13069000.0  14318000.00
# 215   457000.000  ...    815000.00  9.200000e+05    859000.0    915000.00
# 216  1967000.000  ...   2239000.00  2.423000e+06   1794000.0   1833000.00
#
#            2014         2015         2016        2017        2018        2019
# 0     1739000.0   1832000.00   1758000.00   1863000.0   1897000.0   1951000.0
# 1           NaN          NaN          NaN         NaN         NaN         NaN
# 2    10544624.0  13311681.73  13150775.34         NaN         NaN         NaN
# 3      595000.0    592000.00    397000.00    261000.0    218000.0    218000.0
# 4     3673000.0   4131000.00   4736000.00   5118000.0   5927000.0   6406000.0
# ..          ...          ...          ...         ...         ...         ...
# 212         NaN          NaN          NaN         NaN         NaN         NaN
# 213   1218000.0    398000.00          NaN         NaN         NaN         NaN
# 214  14530000.0  13952000.00  15121000.00  14975000.0  15004000.0  14797000.0
# 215    947000.0    932000.00    956000.00   1009000.0   1072000.0   1266000.0
# 216   1880000.0   2057000.00   2168000.00   2423000.0   2580000.0   2294000.0
#
# [217 rows x 29 columns]

# %%
# Format dataframe to long data. 
new_intl_tourism_flights_arrival = intl_tourism_flights_arrival.melt(id_vars=["Country Name", "Country Code", "Latitude", "Longitude"], 
        var_name="Year", 
        value_name="Number of Arrivals")
new_intl_tourism_flights_arrival.head()
# Out:
#                  Country Name Country Code   Latitude  Longitude  Year  \
# 0                       Aruba          ABW  12.490300 -69.960984  1995
# 1                 Afghanistan          AFG  33.768006  66.238514  1995
# 2  Africa Western and Central          AFW   5.267047  28.792421  1995
# 3                      Angola          AGO -11.877577  17.569124  1995
# 4                     Albania          ALB  41.000028  19.999962  1995
#
#    Number of Arrivals
# 0          912000.000
# 1                 NaN
# 2         2670705.934
# 3            9000.000
# 4          304000.000

# %%
# Check and count nulls
new_intl_tourism_flights_arrival.isnull().sum()
# Out:
# Country Name            0
# Country Code            0
# Latitude                0
# Longitude               0
# Year                    0
# Number of Arrivals    886
# dtype: int64

# %%
# Remove nulls
new_intl_tourism_flights_arrival.dropna(inplace=True)
new_intl_tourism_flights_arrival.head()
# Out:
#                  Country Name Country Code   Latitude  Longitude  Year  \
# 0                       Aruba          ABW  12.490300 -69.960984  1995
# 2  Africa Western and Central          AFW   5.267047  28.792421  1995
# 3                      Angola          AGO -11.877577  17.569124  1995
# 4                     Albania          ALB  41.000028  19.999962  1995
# 6        United Arab Emirates          ARE  24.000249  53.999483  1995
#
#    Number of Arrivals
# 0          912000.000
# 2         2670705.934
# 3            9000.000
# 4          304000.000
# 6         2315000.000

# %%
#Check tail of dataframe
new_intl_tourism_flights_arrival.tail()
# Out:
#       Country Name Country Code   Latitude   Longitude  Year  \
# 5418       Vanuatu          VUT -16.525507  168.106915  2019
# 5419         Samoa          WSM -13.769390 -172.120050  2019
# 5422  South Africa          ZAF -28.816624   24.991639  2019
# 5423        Zambia          ZMB -14.518912   27.558988  2019
# 5424      Zimbabwe          ZWE -18.455496   29.746841  2019
#
#       Number of Arrivals
# 5418            256000.0
# 5419            181000.0
# 5422          14797000.0
# 5423           1266000.0
# 5424           2294000.0

# %%
# Save the dataframe as a csv file
new_intl_tourism_flights_arrival.to_csv('new_intl_tourism_flights_arrival.csv')

# %%
number_of_arrivals_per_year = px.scatter_geo(new_intl_tourism_flights_arrival, lat="Latitude", lon="Longitude", color="Year",
                     hover_name="Country Name", size="Number of Arrivals",
                     animation_frame="Year",
                     projection="natural earth",
                    width=1000,
                    height=800)
number_of_arrivals_per_year.show()

# %%
# Checking median
median_arrivals = new_intl_tourism_flights_arrival.groupby(["Year", "Country Name"])["Number of Arrivals"].median()
median_arrivals
# Out:
# Year  Country Name
# 1995  Africa Western and Central    2.670706e+06
#       Albania                       3.040000e+05
#       Algeria                       5.200000e+05
#       Angola                        9.000000e+03
#       Antigua and Barbuda           4.470000e+05
#                                         ...
# 2019  Vanuatu                       2.560000e+05
#       Vietnam                       1.800900e+07
#       Virgin Islands (U.S.)         2.074000e+06
#       Zambia                        1.266000e+06
#       Zimbabwe                      2.294000e+06
# Name: Number of Arrivals, Length: 4539, dtype: float64

# %%
# Checking mean
mean_arrivals = new_intl_tourism_flights_arrival.groupby(["Year", "Country Name"])["Number of Arrivals"].mean()
mean_arrivals
# Out:
# Year  Country Name
# 1995  Africa Western and Central    2.670706e+06
#       Albania                       3.040000e+05
#       Algeria                       5.200000e+05
#       Angola                        9.000000e+03
#       Antigua and Barbuda           4.470000e+05
#                                         ...
# 2019  Vanuatu                       2.560000e+05
#       Vietnam                       1.800900e+07
#       Virgin Islands (U.S.)         2.074000e+06
#       Zambia                        1.266000e+06
#       Zimbabwe                      2.294000e+06
# Name: Number of Arrivals, Length: 4539, dtype: float64

# %%
# Save the dataframe as a csv file
mean_arrivals.to_csv('mean_arrivals.csv')

# %%
# Use hvplot to create an interactive line chart of the mean number of arrivals
average_number_of_arrivals_hvplot = mean_arrivals.hvplot(
    x="Year",
    y="Number of Arrivals",
    kind="line",
    ylabel="Average Number of Arrivals Per Year",
    groupby="Country Name",
    color="purple",
    width=1000,
    height=800
)
average_number_of_arrivals_hvplot
# Out:
# :DynamicMap   [Country Name]
#    :Curve   [Year]   (Number of Arrivals)

# %%
top_10_most_travelled_to_countries = new_intl_tourism_flights_arrival.groupby(["Country Name"]).mean().nlargest(10, "Number of Arrivals").sort_values(ascending=True, by="Number of Arrivals")
top_10_most_travelled_to_countries.reset_index(inplace=True)
top_10_most_travelled_to_countries.head(10)
# Out:
#     Country Name   Latitude   Longitude  Number of Arrivals
# 0         Canada  61.066692 -107.991707        3.506952e+07
# 1        Hungary  47.181758   19.506094        4.085588e+07
# 2        Croatia  45.564344   17.011895        4.404808e+07
# 3          Italy  42.638426   12.674297        7.051658e+07
# 4         Poland  52.215933   19.134422        7.218648e+07
# 5          Spain  39.326069   -4.837979        9.136748e+07
# 6         Mexico  22.500048 -100.000037        9.224772e+07
# 7          China  35.000074  104.999927        1.122087e+08
# 8  United States  39.783730 -100.445882        1.282295e+08
# 9         France  46.603354    1.888334        1.926844e+08

# %%
# Save the dataframe as a csv file
top_10_most_travelled_to_countries.to_csv('top_10_most_travelled_to_countries.csv')

# %%
# Plotting the data from the top 10 most travelled to countries
top_10_most_travelled_to_countries_plot = px.bar(
    top_10_most_travelled_to_countries,
    x="Country Name",
    y="Number of Arrivals",
    range_y=[10000000, 250000000],
    title="Top 10 Most Travelled to Countries",
)
top_10_most_travelled_to_countries_plot

# %%
#geopy in action
country_names = new_intl_tourism_flights_arrival['Country Name']

longitude =[]
latitude =[]
geolocator = Nominatim(user_agent="Arrive")

for c in country_names.values:
    location = geolocator.geocode(c)
    if location is not None:
        latitude.append(location.latitude)
        longitude.append(location.longitude)
    else:
        print(f"Could not find Location for {c!r}")

# %%
new_intl_tourism_flights_arrival['Latitude'] = latitude
new_intl_tourism_flights_arrival['Longitude'] = longitude

# %%
fig = px.scatter_geo(new_intl_tourism_flights_arrival, lat="Country Name", color="continent",
                     hover_name="country", size="Number of Arrivals",
                     animation_frame="Year",
                     projection="natural earth")
fig.show()

# %%
intl_tourism_flights_arrival.columns

# %%
#Delete columns not needed
intl_tourism_flights_arrival.drop([
    'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2020'], axis = 1, inplace=True)

# %%
intl_tourism_flights_arrival.head()

# %%
intl_tourism_flights_arrival.isnull().sum()

# %%
intl_tourism_flights_arrival.dropna(inplace=True)
intl_tourism_flights_arrival.head()

# %%
#geopy in action
country_names = intl_tourism_flights_arrival['Country Name']

longitude =[]
latitude =[]
geolocator = Nominatim(user_agent="Arrive")

for c in country_names.values:
    location = geolocator.geocode(c)
    if location is not None:
        latitude.append(location.latitude)
        longitude.append(location.longitude)
    else:
        print(f"Could not find Location for {c!r}")

# %%
intl_tourism_flights_arrival['Latitude'] = latitude
intl_tourism_flights_arrival['Longitude'] = longitude

# %%
intl_tourism_flights_arrival.head()

# %%
#intl_tourism_flights_arrival.isnull().sum()

# %%
#intl_tourism_flights_arrival.dropna(inplace=True)
#intl_tourism_flights_arrival.head()

# %%
# Create a scatter geo to analyze 2019 international tourist arrivals info https://plotly.com/python/scattermapbox/
scatter_geo = px.scatter_geo(
    intl_tourism_flights_arrival, 
    lat="Latitude", 
    lon="Longitude",     
    color="Country Code", 
    size="2019",
    title="2019 International Tourist Arrivals",
    color_continuous_scale=px.colors.sequential.Inferno, 
    hover_name="Country Name",
    projection="equirectangular",
    #size=20,
    #zoom=10,
    width=1000, 
    height=1000
)
scatter_geo.show()

# %%
plt.figure(figsize=(20,20))
plt.imshow(WordCloud().generate("Country Name"))

# %%
#density_mapbox = px.density_mapbox(intl_tourism_flights_arrival, lat="Latitude", lon="Longitude", z="2019", center=dict(lat=0, lon=180), radius=20, zoom=0, hover_name="Country Name",
                        #mapbox_style="satellite", width=1000, height=1000)
#density_mapbox.show()
